# %% [markdown]
# # Wine text analysis
#
# I've provided you with `wine-reviews.csv`. Based on what we did in class today, build a classifier that uses the wine description to predict any of the categorical columns (variety, category, etc...).

# %%
import pandas as pd

# Show 200 characters of the wine description
pd.options.display.max_colwidth = 200


df = pd.read_csv("wine-reviews.csv")
df.head(3)
# Out:
#                                                                                                                                  url  \
# 0                                                     https://www.winemag.com/buying-guide/artadi-2011-vinas-gain-tempranillo-rioja/
# 1                    https://www.winemag.com/buying-guide/adelsheim-2012-stoller-vineyard-chardonnay-willamette-valley-dundee-hills/
# 2  https://www.winemag.com/buying-guide/adelsheim-2013-ribbon-springs-vineyard-other-white-auxerrois-willamette-valley-ribbon-ridge/
#
#    wine_points  \
# 0         90.0
# 1         90.0
# 2         90.0
#
#                                                          wine_name  \
# 0                               Artadi 2011 Viñas de Gain  (Rioja)
# 1        Adelsheim 2012 Stoller Vineyard Chardonnay (Dundee Hills)
# 2  Adelsheim 2013 Ribbon Springs Vineyard Auxerrois (Ribbon Ridge)
#
#                                                                                                                                                                                                  wine_desc  \
# 0  Inky, minerally aromas of blackberry, black plum and coconut filter into a round, fluffy palate that's friendly and pure but not very dense or structured. Baked flavors of molasses and gamy berry ...
# 1  A tiny production wine, this is rich, tart and vividly fruity. The generous mix of citrus, apple and peach fruit is augmented by barrel fermentation flavors of toasted hazelnuts, caramel and bakin...
# 2  This is another fine vintage for this rare wine. It's loaded with cool climate, mineral-laced scents of grapefruit, kiwi and melon. A whiff of fennel adds further interest. Super refreshing and a ...
#
#               taster          price              designation  \
# 0  Michael Schachner  $25,  Buy Now            Viñas de Gain
# 1       Paul Gregutt  $65,  Buy Now         Stoller Vineyard
# 2       Paul Gregutt  $25,  Buy Now  Ribbon Springs Vineyard
#
#                   variety                                  appellation  \
# 0             Tempranillo                 Rioja, Northern Spain, Spain
# 1              Chardonnay  Dundee Hills, Willamette Valley, Oregon, US
# 2  Auxerrois, Other White  Ribbon Ridge, Willamette Valley, Oregon, US
#
#       winery alcohol bottle size category                  importer  \
# 0     Artadi   14.5%      750 ml      Red  Folio Fine Wine Partners
# 1  Adelsheim   13.5%      750 ml    White                       NaN
# 2  Adelsheim   13.5%      750 ml    White                       NaN
#
#   date published                  user avg rating
# 0      12/1/2014  Not rated yet [Add Your Review]
# 1      12/1/2014  Not rated yet [Add Your Review]
# 2      12/1/2014  Not rated yet [Add Your Review]

# %% [markdown]
# _**...but first!!!**_
#
# ### Converting categories into numbers
#
# You'll run into two issues:
#
# 1. scikit-learn can only predict numbers
# 2. Not every classifier can do multi-class classification (some only predict 0/1 binary classification)
#
# You'll learn the second one through trial and error with different classifiers (or by reading [this page](https://scikit-learn.org/stable/modules/multiclass.html) and probably just using one of the "inherently multiclass" algorithms), but let's fix the first one for you.
#
# **In this example, we'll convert the `importer` into a category.** (This is probably the dumbest thign to try to predict. Don't use it, adapt it to the column you're interested in.)
#
# ```python
# from sklearn.preprocessing import LabelEncoder
#
# # Create a Label Encoder to memorize the categories
# # and convert them to numbers
# le = LabelEncoder()
#
# # fit memorizes the categories
# # transform converts them into numbers
# df['importer_int'] = le.fit_transform(df.importer)
#
# # check the new importer_int column
# df.head()
# ```

# %%
from sklearn.preprocessing import LabelEncoder

# Create a Label Encoder to memorize the categories
# and convert them to numbers
le = LabelEncoder()

# fit memorizes the categories
# transform converts them into numbers
df['importer_int'] = le.fit_transform(df.importer)

# check the new importer_int column
df.head()
# Out:
#                                                                                                                                  url  \
# 0                                                     https://www.winemag.com/buying-guide/artadi-2011-vinas-gain-tempranillo-rioja/
# 1                    https://www.winemag.com/buying-guide/adelsheim-2012-stoller-vineyard-chardonnay-willamette-valley-dundee-hills/
# 2  https://www.winemag.com/buying-guide/adelsheim-2013-ribbon-springs-vineyard-other-white-auxerrois-willamette-valley-ribbon-ridge/
# 3                                                       https://www.winemag.com/buying-guide/jcb-2011-no-11-pinot-noir-sonoma-coast/
# 4                                                        https://www.winemag.com/buying-guide/pazo-pondal-2013-albarino-rias-baixas/
#
#    wine_points  \
# 0         90.0
# 1         90.0
# 2         90.0
# 3         90.0
# 4         90.0
#
#                                                          wine_name  \
# 0                               Artadi 2011 Viñas de Gain  (Rioja)
# 1        Adelsheim 2012 Stoller Vineyard Chardonnay (Dundee Hills)
# 2  Adelsheim 2013 Ribbon Springs Vineyard Auxerrois (Ribbon Ridge)
# 3                        JCB 2011 No. 11 Pinot Noir (Sonoma Coast)
# 4                          Pazo Pondal 2013 Albariño (Rías Baixas)
#
#                                                                                                                                                                                                  wine_desc  \
# 0  Inky, minerally aromas of blackberry, black plum and coconut filter into a round, fluffy palate that's friendly and pure but not very dense or structured. Baked flavors of molasses and gamy berry ...
# 1  A tiny production wine, this is rich, tart and vividly fruity. The generous mix of citrus, apple and peach fruit is augmented by barrel fermentation flavors of toasted hazelnuts, caramel and bakin...
# 2  This is another fine vintage for this rare wine. It's loaded with cool climate, mineral-laced scents of grapefruit, kiwi and melon. A whiff of fennel adds further interest. Super refreshing and a ...
# 3                                    Light in color and lilting floral aromas of rose, this is an inviting cool-climate Pinot Noir swirling in equal parts strawberry and spice, subtle and sophisticated.
# 4  Alluring, inviting aromas of white flowers, melon and peach are pure as stream water. This feels round and juicy, with flavors of green herbs, lettuce, lime and orange. Tangerine notes carry the f...
#
#               taster          price              designation  \
# 0  Michael Schachner  $25,  Buy Now            Viñas de Gain
# 1       Paul Gregutt  $65,  Buy Now         Stoller Vineyard
# 2       Paul Gregutt  $25,  Buy Now  Ribbon Springs Vineyard
# 3     Virginie Boone  $65,  Buy Now                   No. 11
# 4  Michael Schachner  $17,  Buy Now                      NaN
#
#                   variety                                  appellation  \
# 0             Tempranillo                 Rioja, Northern Spain, Spain
# 1              Chardonnay  Dundee Hills, Willamette Valley, Oregon, US
# 2  Auxerrois, Other White  Ribbon Ridge, Willamette Valley, Oregon, US
# 3              Pinot Noir         Sonoma Coast, Sonoma, California, US
# 4                Albariño                  Rías Baixas, Galicia, Spain
#
#         winery alcohol bottle size category                  importer  \
# 0       Artadi   14.5%      750 ml      Red  Folio Fine Wine Partners
# 1    Adelsheim   13.5%      750 ml    White                       NaN
# 2    Adelsheim   13.5%      750 ml    White                       NaN
# 3          JCB     13%      750 ml      Red                       NaN
# 4  Pazo Pondal     13%      750 ml    White            Vinaio Imports
#
#   date published                  user avg rating  importer_int
# 0      12/1/2014  Not rated yet [Add Your Review]           717
# 1      12/1/2014  Not rated yet [Add Your Review]          1952
# 2      12/1/2014  Not rated yet [Add Your Review]          1952
# 3      12/1/2014  Not rated yet [Add Your Review]          1952
# 4      12/1/2014  Not rated yet [Add Your Review]          1740

# %% [markdown]
# After you do your predicting, you'll have a column of numbers that you'll want to convert back into words for easy reading. You'll use `le.inverse_transform` for that.
#
# For example, we can convert the `category_int` column back into a `category_str` column.
#
# ```python
# df['category_str'] = le.inverse_transform(df.category_int)
# ```

# %%
df['importer_str'] = le.inverse_transform(df.importer_int)

df.head()
# Out:
#                                                                                                                                  url  \
# 0                                                     https://www.winemag.com/buying-guide/artadi-2011-vinas-gain-tempranillo-rioja/
# 1                    https://www.winemag.com/buying-guide/adelsheim-2012-stoller-vineyard-chardonnay-willamette-valley-dundee-hills/
# 2  https://www.winemag.com/buying-guide/adelsheim-2013-ribbon-springs-vineyard-other-white-auxerrois-willamette-valley-ribbon-ridge/
# 3                                                       https://www.winemag.com/buying-guide/jcb-2011-no-11-pinot-noir-sonoma-coast/
# 4                                                        https://www.winemag.com/buying-guide/pazo-pondal-2013-albarino-rias-baixas/
#
#    wine_points  \
# 0         90.0
# 1         90.0
# 2         90.0
# 3         90.0
# 4         90.0
#
#                                                          wine_name  \
# 0                               Artadi 2011 Viñas de Gain  (Rioja)
# 1        Adelsheim 2012 Stoller Vineyard Chardonnay (Dundee Hills)
# 2  Adelsheim 2013 Ribbon Springs Vineyard Auxerrois (Ribbon Ridge)
# 3                        JCB 2011 No. 11 Pinot Noir (Sonoma Coast)
# 4                          Pazo Pondal 2013 Albariño (Rías Baixas)
#
#                                                                                                                                                                                                  wine_desc  \
# 0  Inky, minerally aromas of blackberry, black plum and coconut filter into a round, fluffy palate that's friendly and pure but not very dense or structured. Baked flavors of molasses and gamy berry ...
# 1  A tiny production wine, this is rich, tart and vividly fruity. The generous mix of citrus, apple and peach fruit is augmented by barrel fermentation flavors of toasted hazelnuts, caramel and bakin...
# 2  This is another fine vintage for this rare wine. It's loaded with cool climate, mineral-laced scents of grapefruit, kiwi and melon. A whiff of fennel adds further interest. Super refreshing and a ...
# 3                                    Light in color and lilting floral aromas of rose, this is an inviting cool-climate Pinot Noir swirling in equal parts strawberry and spice, subtle and sophisticated.
# 4  Alluring, inviting aromas of white flowers, melon and peach are pure as stream water. This feels round and juicy, with flavors of green herbs, lettuce, lime and orange. Tangerine notes carry the f...
#
#               taster          price              designation  \
# 0  Michael Schachner  $25,  Buy Now            Viñas de Gain
# 1       Paul Gregutt  $65,  Buy Now         Stoller Vineyard
# 2       Paul Gregutt  $25,  Buy Now  Ribbon Springs Vineyard
# 3     Virginie Boone  $65,  Buy Now                   No. 11
# 4  Michael Schachner  $17,  Buy Now                      NaN
#
#                   variety                                  appellation  \
# 0             Tempranillo                 Rioja, Northern Spain, Spain
# 1              Chardonnay  Dundee Hills, Willamette Valley, Oregon, US
# 2  Auxerrois, Other White  Ribbon Ridge, Willamette Valley, Oregon, US
# 3              Pinot Noir         Sonoma Coast, Sonoma, California, US
# 4                Albariño                  Rías Baixas, Galicia, Spain
#
#         winery alcohol bottle size category                  importer  \
# 0       Artadi   14.5%      750 ml      Red  Folio Fine Wine Partners
# 1    Adelsheim   13.5%      750 ml    White                       NaN
# 2    Adelsheim   13.5%      750 ml    White                       NaN
# 3          JCB     13%      750 ml      Red                       NaN
# 4  Pazo Pondal     13%      750 ml    White            Vinaio Imports
#
#   date published                  user avg rating  importer_int  \
# 0      12/1/2014  Not rated yet [Add Your Review]           717
# 1      12/1/2014  Not rated yet [Add Your Review]          1952
# 2      12/1/2014  Not rated yet [Add Your Review]          1952
# 3      12/1/2014  Not rated yet [Add Your Review]          1952
# 4      12/1/2014  Not rated yet [Add Your Review]          1740
#
#                importer_str
# 0  Folio Fine Wine Partners
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4            Vinaio Imports

# %% [markdown]
# ## Okay, off to work with you!
#
# Eventually let's see a **confusion matrix** with the best scores you can come up with.
